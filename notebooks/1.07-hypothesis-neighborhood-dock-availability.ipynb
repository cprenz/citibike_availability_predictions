# %% [markdown]
# # Hypothesis 7 — Do tourist-heavy and residential neighborhoods differ in dock availability?
#
# **H0: mean dock availability is equal between tourist-heavy and residential neighborhoods.**
#
# **H1: dock availability differs between tourist-heavy and residential neighborhoods.**
#
# - **Metric:** Mean num_docks_available per station-hour.
# - **Groups:** Group A = stations in tourist-heavy areas; Group B = stations in residential areas (neighborhood proxy).
# - **Test:** Shapiro-Wilk -> two-sample t-test (or Mann-Whitney U if non-normal)
#
# See `docs/statistical_analysis.md` for the full procedure.

# %% [markdown]
# ## 1. Setup

# %%
import pandas as pd
from scipy import stats

from citibike.dataset import query  # run notebooks from the project root

# %% [markdown]
# ## 2. Extract the two groups from the database

# %%
# TODO: write SQL to pull Group A and Group B
# group_a = query("""...""")
# group_b = query("""...""")

# %% [markdown]
# ## 3. Normality check (Shapiro-Wilk)

# %%
# stats.shapiro(group_a)  ;  stats.shapiro(group_b)

# %% [markdown]
# ## 4. Hypothesis test + 95% confidence interval

# %%
# t-test if normal, else Mann-Whitney U
# stats.ttest_ind(group_a, group_b, equal_var=False)
# report p-value AND the 95% CI for the difference

# %% [markdown]
# ## 5. Conclusion
#
# _Report p-value and CI. Reject H0 if p < 0.05; comment on practical significance._
